# %%
import pandas as pd

# %%
data = pd.read_csv("../input/masterclass/Walmart.csv")
data

# %%
data.dropna(how= "all", inplace= True)

# %%
data

# %%
data["Country"].replace({"United States": "USA"}, inplace= True)

# %%
data

# %%
avg= data["Sales"].mean()

# %%
avg

# %%
data.fillna(value= avg, inplace= True)

# %%
data

# %%
data.to_csv("walmart_data.csv")
